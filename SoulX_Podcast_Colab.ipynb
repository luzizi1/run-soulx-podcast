# %% [markdown]
# # SoulX-Podcast Google Colab 运行指南
#
# **重要提示**：如果之前运行报错，请先点击上方菜单栏的 **Runtime (运行时)** -> **Disconnect and delete runtime (断开连接并删除运行时)**，确保环境纯净。
#
# 然后点击 **Runtime** -> **Change runtime type** -> 选择 **T4 GPU**。
#
# 依次点击下方单元格左侧的 **播放按钮** 运行。

# %%
# 1. 检查显卡
# !nvidia-smi
# Out:
# Sun Jan 18 15:03:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# 2. 克隆项目
# !git clone https://github.com/Soul-AILab/SoulX-Podcast.git
# %cd SoulX-Podcast
# Out:
# Cloning into 'SoulX-Podcast'...
# remote: Enumerating objects: 401, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 401 (delta 94), reused 82 (delta 82), pack-reused 294 (from 2)
# Receiving objects: 100% (401/401), 185.20 MiB | 30.47 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# /content/SoulX-Podcast

# %%
# 2. 安装依赖 (自动修复版)
import os
if os.getcwd() != "/content/SoulX-Podcast":
    os.chdir("/content/SoulX-Podcast")

# A. 基础库降级与安装 (SoundFile是关键)
# 显式安装 soundfile 以支持 audio load
# !pip install soundfile
# !pip install "numpy<2.0"

# B. 修复 requirements.txt
# !sed -i '/torch/d' requirements.txt
# !sed -i 's/numba==0.57.1/numba/' requirements.txt
# !sed -i 's/llvmlite==0.40.1/llvmlite/' requirements.txt

# C. 安装其他依赖
# !pip install -r requirements.txt
# !pip install gradio

# %%
# 4. 下载模型
# !pip install huggingface_hub
# !huggingface-cli download --resume-download Soul-AILab/SoulX-Podcast-1.7B --local-dir pretrained_models/SoulX-Podcast-1.7B
# !huggingface-cli download --resume-download Soul-AILab/SoulX-Podcast-1.7B-dialect --local-dir pretrained_models/SoulX-Podcast-1.7B-dialect
# Out:
# ...
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 28 files:   0% 0/28 [00:00<?, ?it/s]Downloading 'flow.cache.pt' to 'pretrained_models/SoulX-Podcast-1.7B/.cache/huggingface/download/k9iOHt-nAW8sgvnKqwuabz3u_HU=.3ebde248652c6eed855e08bb6a263af3847039a1361f8019bdb27f5f680a1dc4.incomplete' (resume from 450496991/450496991)
# ...
#
# flow.cache.pt:   0% 0.00/450M [00:00<?, ?B/s]
#
# flow.encoder.fp32.zip:   0% 0.00/192M [00:00<?, ?B/s]
#
#
# flow.pt:   0% 0.00/451M [00:00<?, ?B/s]
#
#
#
# model-00003-of-00003.safetensors:   0% 0.00/653M [00:00<?, ?B/s]
#
#
#
#
# model-00001-of-00003.safetensors:   0% 0.00/1.99G [00:00<?, ?B/s]
#
#
#
#
#
# ...

# %%
# 重新安装 torchcodec
# !pip install --upgrade --no-cache-dir torchcodec
print("已重新安装 torchcodec")
# 5. 开启公网访问
# !sed -i 's/share=False/share=True/g' webui.py
print("已开启公网分享功能")
# Out:
# 已开启公网分享功能

# %%
# 重新安装 torchcodec
# !pip install --upgrade --no-cache-dir torchcodec
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 65.3 MB/s eta 0:00:00
# ...

# %%
print('正在尝试安装兼容的 torchcodec 版本...')
# !pip uninstall -y torchcodec
# !pip install torchcodec==0.9.0
print('torchcodec 0.9.0 已尝试安装。请重新运行启动 Web UI 的单元格。')

# %%
# 6. 开启公网并启动
import os
if os.getcwd() != "/content/SoulX-Podcast":
    os.chdir("/content/SoulX-Podcast")

# !sed -i 's/share=False/share=True/g' webui.py
print("Web UI Starting... Click the 'gradio.live' link below when it appears.")

# !python webui.py --model_path pretrained_models/SoulX-Podcast-1.7B --port 7860
